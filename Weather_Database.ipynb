# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
# Generate 2000 random latitudes and longitudes, and zip them as a list of tuples
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# Get the nearest city using the citipy module.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)

# %%
record_count = 1 
set_count = 1

city_data = []
url = "http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=" + weather_api_key

print('Beginning Data Retrieval     ')
print("-----------------------------")
# Group cities in sets of 50
for i, city in enumerate(cities):
    if (i % 50 == 0 and i >=50) :
        record_count = 1  
        set_count +=1 
    # build URL for API call
    full_url = url + '&q=' + city.replace(" ","+")
    print(full_url)
    # Log the URL, record, and set numbers and the city.
    print(f'Processing Record {record_count} of Set {set_count} | {city}')
    record_count +=1
    
    try:
        js = requests.get(full_url).json()
        country = js['sys']['country']
        #city_date = datetime.utcfromtimestamp(js["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        lat = js['coord']['lat']
        lng = js['coord']['lon']
        max_temp = js['main']['temp_max']
        humidity = js['main']['humidity']
        cloud = js['clouds']['all']
        wind_speed = js['wind']['speed']
        weather_description = js['weather'][0]['description']
       
        
        # append as a list of dictionaries
        city_data.append({'City':city, 'Country':country, 'Lat':lat, 'Lng': lng,'Max Temp':max_temp,
                        'Humidity':humidity,'Cloudiness': cloud,'Wind Speed':wind_speed,
                        'Current Description':weather_description})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass 
    
print('-------------------------------')
print('Data Retrieval Complete        ')
print('-------------------------------')

print(len(city_data))

# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)

# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=yellowknife
# Processing Record 1 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ostrovnoy
# Processing Record 2 of Set 1 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ushuaia
# Processing Record 3 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=concordia
# Processing Record 4 of Set 1 | concordia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=klaksvik
# Processing Record 5 of Set 1 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=khatanga
# Processing Record 6 of Set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=karachi
# Processing Record 7 of Set 1 | karachi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rikitea
# Processing Record 8 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bambous+virieux
# Processing Record 9 of Set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=seoul
# Processing Record 10 of Set 1 | seoul
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=thinadhoo
# Processing Record 11 of Set 1 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tuktoyaktuk
# Processing Record 12 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=codrington
# Processing Record 13 of Set 1 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=miyako
# Processing Record 14 of Set 1 | miyako
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=albany
# Processing Record 15 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=yulara
# Processing Record 16 of Set 1 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bluff
# Processing Record 17 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hithadhoo
# Processing Record 18 of Set 1 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bredasdorp
# Processing Record 19 of Set 1 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=grand+river+south+east
# Processing Record 20 of Set 1 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ola
# Processing Record 21 of Set 1 | ola
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=barroquinha
# Processing Record 22 of Set 1 | barroquinha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=barrow
# Processing Record 23 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=namibe
# Processing Record 24 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ribeira+grande
# Processing Record 25 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lagoa
# Processing Record 26 of Set 1 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=castro
# Processing Record 27 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=deltona
# Processing Record 28 of Set 1 | deltona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ciro+marina
# Processing Record 29 of Set 1 | ciro marina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=busselton
# Processing Record 30 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mataura
# Processing Record 31 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=touros
# Processing Record 32 of Set 1 | touros
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=illoqqortoormiut
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chokurdakh
# Processing Record 34 of Set 1 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chifeng
# Processing Record 35 of Set 1 | chifeng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=karpathos
# Processing Record 36 of Set 1 | karpathos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=petrovsk
# Processing Record 37 of Set 1 | petrovsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sasaram
# Processing Record 38 of Set 1 | sasaram
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=grand-santi
# Processing Record 39 of Set 1 | grand-santi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=butaritari
# Processing Record 40 of Set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=manggar
# Processing Record 41 of Set 1 | manggar
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sorvag
# Processing Record 42 of Set 1 | sorvag
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=punta+arenas
# Processing Record 43 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=isangel
# Processing Record 44 of Set 1 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=souillac
# Processing Record 45 of Set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vaini
# Processing Record 46 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=puerto+ayora
# Processing Record 47 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saskylakh
# Processing Record 48 of Set 1 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+hardy
# Processing Record 49 of Set 1 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=fort+frances
# Processing Record 50 of Set 1 | fort frances
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=okhotsk
# Processing Record 1 of Set 2 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saint+george
# Processing Record 2 of Set 2 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kieta
# Processing Record 3 of Set 2 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bagdarin
# Processing Record 4 of Set 2 | bagdarin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cape+canaveral
# Processing Record 5 of Set 2 | cape canaveral
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tumannyy
# Processing Record 6 of Set 2 | tumannyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hilo
# Processing Record 7 of Set 2 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=huarmey
# Processing Record 8 of Set 2 | huarmey
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kupang
# Processing Record 9 of Set 2 | kupang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cap+malheureux
# Processing Record 10 of Set 2 | cap malheureux
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=wuda
# Processing Record 11 of Set 2 | wuda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tasiilaq
# Processing Record 12 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kapaa
# Processing Record 13 of Set 2 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cape+town
# Processing Record 14 of Set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=casablanca
# Processing Record 15 of Set 2 | casablanca
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nanortalik
# Processing Record 16 of Set 2 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vanimo
# Processing Record 17 of Set 2 | vanimo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=constantine
# Processing Record 18 of Set 2 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bajos+de+haina
# Processing Record 19 of Set 2 | bajos de haina
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bouna
# Processing Record 20 of Set 2 | bouna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mount+gambier
# Processing Record 21 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mar+del+plata
# Processing Record 22 of Set 2 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=peterhead
# Processing Record 23 of Set 2 | peterhead
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lolua
# Processing Record 24 of Set 2 | lolua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=torbay
# Processing Record 25 of Set 2 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=karamay
# Processing Record 26 of Set 2 | karamay
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=flinders
# Processing Record 27 of Set 2 | flinders
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=asfi
# Processing Record 28 of Set 2 | asfi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=east+london
# Processing Record 29 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=skegness
# Processing Record 30 of Set 2 | skegness
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tabiauea
# Processing Record 31 of Set 2 | tabiauea
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=luau
# Processing Record 32 of Set 2 | luau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=palabuhanratu
# Processing Record 33 of Set 2 | palabuhanratu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=labrea
# Processing Record 34 of Set 2 | labrea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=olafsvik
# Processing Record 35 of Set 2 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mayo
# Processing Record 36 of Set 2 | mayo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=taolanaro
# Processing Record 37 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mahebourg
# Processing Record 38 of Set 2 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=japura
# Processing Record 39 of Set 2 | japura
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=acarau
# Processing Record 40 of Set 2 | acarau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mayya
# Processing Record 41 of Set 2 | mayya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hobart
# Processing Record 42 of Set 2 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=iracoubo
# Processing Record 43 of Set 2 | iracoubo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kununurra
# Processing Record 44 of Set 2 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kruisfontein
# Processing Record 45 of Set 2 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ixtapa
# Processing Record 46 of Set 2 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+alfred
# Processing Record 47 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=atuona
# Processing Record 48 of Set 2 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ankazobe
# Processing Record 49 of Set 2 | ankazobe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=stoyba
# Processing Record 50 of Set 2 | stoyba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mehamn
# Processing Record 1 of Set 3 | mehamn
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=el+sauzal
# Processing Record 2 of Set 3 | el sauzal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hermanus
# Processing Record 3 of Set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kavieng
# Processing Record 4 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=machaneng
# Processing Record 5 of Set 3 | machaneng
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=labutta
# Processing Record 6 of Set 3 | labutta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rudnya
# Processing Record 7 of Set 3 | rudnya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=puerto+escondido
# Processing Record 8 of Set 3 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=coihaique
# Processing Record 9 of Set 3 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=beyneu
# Processing Record 10 of Set 3 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tucuman
# Processing Record 11 of Set 3 | tucuman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=xining
# Processing Record 12 of Set 3 | xining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=new+norfolk
# Processing Record 13 of Set 3 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kloulklubed
# Processing Record 14 of Set 3 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=severo-kurilsk
# Processing Record 15 of Set 3 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=dikson
# Processing Record 16 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=fort+nelson
# Processing Record 17 of Set 3 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=agadir
# Processing Record 18 of Set 3 | agadir
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=akyab
# Processing Record 19 of Set 3 | akyab
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=marsa+matruh
# Processing Record 20 of Set 3 | marsa matruh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bethel
# Processing Record 21 of Set 3 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=havre-saint-pierre
# Processing Record 22 of Set 3 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=yertarskiy
# Processing Record 23 of Set 3 | yertarskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=srednekolymsk
# Processing Record 24 of Set 3 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=attawapiskat
# Processing Record 25 of Set 3 | attawapiskat
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=karkaralinsk
# Processing Record 26 of Set 3 | karkaralinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=marcona
# Processing Record 27 of Set 3 | marcona
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=georgetown
# Processing Record 28 of Set 3 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=prince+albert
# Processing Record 29 of Set 3 | prince albert
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=goderich
# Processing Record 30 of Set 3 | goderich
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=carnarvon
# Processing Record 31 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sorland
# Processing Record 32 of Set 3 | sorland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vao
# Processing Record 33 of Set 3 | vao
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ostroleka
# Processing Record 34 of Set 3 | ostroleka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=esperance
# Processing Record 35 of Set 3 | esperance
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=forbes
# Processing Record 36 of Set 3 | forbes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=batemans+bay
# Processing Record 37 of Set 3 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=novyy+urengoy
# Processing Record 38 of Set 3 | novyy urengoy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=grand+gaube
# Processing Record 39 of Set 3 | grand gaube
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=babanusah
# Processing Record 40 of Set 3 | babanusah
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=fairbanks
# Processing Record 41 of Set 3 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=airai
# Processing Record 42 of Set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chapais
# Processing Record 43 of Set 3 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=pangody
# Processing Record 44 of Set 3 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=quetzaltepec
# Processing Record 45 of Set 3 | quetzaltepec
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lavumisa
# Processing Record 46 of Set 3 | lavumisa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kutum
# Processing Record 47 of Set 3 | kutum
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=edson
# Processing Record 48 of Set 3 | edson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mexticacan
# Processing Record 49 of Set 3 | mexticacan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=andenes
# Processing Record 50 of Set 3 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kaeo
# Processing Record 1 of Set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mahibadhoo
# Processing Record 2 of Set 4 | mahibadhoo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=itoman
# Processing Record 3 of Set 4 | itoman
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chiang+khong
# Processing Record 4 of Set 4 | chiang khong
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tautira
# Processing Record 5 of Set 4 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mareeba
# Processing Record 6 of Set 4 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=thompson
# Processing Record 7 of Set 4 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saint-philippe
# Processing Record 8 of Set 4 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mys+shmidta
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nouadhibou
# Processing Record 10 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bengkulu
# Processing Record 11 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=salalah
# Processing Record 12 of Set 4 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vila+velha
# Processing Record 13 of Set 4 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=samusu
# Processing Record 14 of Set 4 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=havelock
# Processing Record 15 of Set 4 | havelock
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vsevolodo-vilva
# Processing Record 16 of Set 4 | vsevolodo-vilva
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=siteki
# Processing Record 17 of Set 4 | siteki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=falesti
# Processing Record 18 of Set 4 | falesti
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hovd
# Processing Record 19 of Set 4 | hovd
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=usolye
# Processing Record 20 of Set 4 | usolye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=conde
# Processing Record 21 of Set 4 | conde
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vostok
# Processing Record 22 of Set 4 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=samarai
# Processing Record 23 of Set 4 | samarai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=portland
# Processing Record 24 of Set 4 | portland
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tomatlan
# Processing Record 25 of Set 4 | tomatlan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cidreira
# Processing Record 26 of Set 4 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=derzhavinsk
# Processing Record 27 of Set 4 | derzhavinsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=qaanaaq
# Processing Record 28 of Set 4 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kilindoni
# Processing Record 29 of Set 4 | kilindoni
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cayenne
# Processing Record 30 of Set 4 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bikaner
# Processing Record 31 of Set 4 | bikaner
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=arraial+do+cabo
# Processing Record 32 of Set 4 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kepno
# Processing Record 33 of Set 4 | kepno
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=jamestown
# Processing Record 34 of Set 4 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=pucallpa
# Processing Record 35 of Set 4 | pucallpa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kirakira
# Processing Record 36 of Set 4 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lebu
# Processing Record 37 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=honiara
# Processing Record 38 of Set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=north+bend
# Processing Record 39 of Set 4 | north bend
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lucea
# Processing Record 40 of Set 4 | lucea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sentyabrskiy
# Processing Record 41 of Set 4 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=louisbourg
# Processing Record 42 of Set 4 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=yining
# Processing Record 43 of Set 4 | yining
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kiruna
# Processing Record 44 of Set 4 | kiruna
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vardo
# Processing Record 45 of Set 4 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kinston
# Processing Record 46 of Set 4 | kinston
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nikolskoye
# Processing Record 47 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=jalpan
# Processing Record 48 of Set 4 | jalpan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=praia+da+vitoria
# Processing Record 49 of Set 4 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=urdzhar
# Processing Record 50 of Set 4 | urdzhar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=aklavik
# Processing Record 1 of Set 5 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=geraldton
# Processing Record 2 of Set 5 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=biharamulo
# Processing Record 3 of Set 5 | biharamulo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=barbar
# Processing Record 4 of Set 5 | barbar
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=wuhu
# Processing Record 5 of Set 5 | wuhu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cancun
# Processing Record 6 of Set 5 | cancun
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tayu
# Processing Record 7 of Set 5 | tayu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+blair
# Processing Record 8 of Set 5 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mantua
# Processing Record 9 of Set 5 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sergiyevsk
# Processing Record 10 of Set 5 | sergiyevsk
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=umzimvubu
# Processing Record 11 of Set 5 | umzimvubu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=beloha
# Processing Record 12 of Set 5 | beloha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chiriqui+grande
# Processing Record 13 of Set 5 | chiriqui grande
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ewa+beach
# Processing Record 14 of Set 5 | ewa beach
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=uvat
# Processing Record 15 of Set 5 | uvat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=araouane
# Processing Record 16 of Set 5 | araouane
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rio+gallegos
# Processing Record 17 of Set 5 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=alofi
# Processing Record 18 of Set 5 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=belushya+guba
# Processing Record 19 of Set 5 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=skalistyy
# Processing Record 20 of Set 5 | skalistyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=amderma
# Processing Record 21 of Set 5 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=broken+hill
# Processing Record 22 of Set 5 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=shaowu
# Processing Record 23 of Set 5 | shaowu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mattawa
# Processing Record 24 of Set 5 | mattawa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=victoria
# Processing Record 25 of Set 5 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+elizabeth
# Processing Record 26 of Set 5 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chagda
# Processing Record 27 of Set 5 | chagda
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=konstantinovskiy
# Processing Record 28 of Set 5 | konstantinovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kodiak
# Processing Record 29 of Set 5 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=requena
# Processing Record 30 of Set 5 | requena
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=weligama
# Processing Record 31 of Set 5 | weligama
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=arvika
# Processing Record 32 of Set 5 | arvika
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=deputatskiy
# Processing Record 33 of Set 5 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tiksi
# Processing Record 34 of Set 5 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=shobara
# Processing Record 35 of Set 5 | shobara
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sambava
# Processing Record 36 of Set 5 | sambava
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=coquimbo
# Processing Record 37 of Set 5 | coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=stornoway
# Processing Record 38 of Set 5 | stornoway
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tarudant
# Processing Record 39 of Set 5 | tarudant
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=upernavik
# Processing Record 40 of Set 5 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=norman+wells
# Processing Record 41 of Set 5 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chuy
# Processing Record 42 of Set 5 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ceres
# Processing Record 43 of Set 5 | ceres
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=boljoon
# Processing Record 44 of Set 5 | boljoon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=oranjemund
# Processing Record 45 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=shingu
# Processing Record 46 of Set 5 | shingu
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=samalaeulu
# Processing Record 47 of Set 5 | samalaeulu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hambantota
# Processing Record 48 of Set 5 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=cabedelo
# Processing Record 49 of Set 5 | cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=pemberton
# Processing Record 50 of Set 5 | pemberton
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port-gentil
# Processing Record 1 of Set 6 | port-gentil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ryazanovskiy
# Processing Record 2 of Set 6 | ryazanovskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=half+moon+bay
# Processing Record 3 of Set 6 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=dauphin
# Processing Record 4 of Set 6 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nueva+guinea
# Processing Record 5 of Set 6 | nueva guinea
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=aginskoye
# Processing Record 6 of Set 6 | aginskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saldanha
# Processing Record 7 of Set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tsaratanana
# Processing Record 8 of Set 6 | tsaratanana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kingsport
# Processing Record 9 of Set 6 | kingsport
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nizhniy+kuranakh
# Processing Record 10 of Set 6 | nizhniy kuranakh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=narok
# Processing Record 11 of Set 6 | narok
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=theologos
# Processing Record 12 of Set 6 | theologos
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=warqla
# Processing Record 13 of Set 6 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mbuji-mayi
# Processing Record 14 of Set 6 | mbuji-mayi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=murgab
# Processing Record 15 of Set 6 | murgab
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hauterive
# Processing Record 16 of Set 6 | hauterive
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=frederico+westphalen
# Processing Record 17 of Set 6 | frederico westphalen
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nizhneyansk
# Processing Record 18 of Set 6 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tuatapere
# Processing Record 19 of Set 6 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=new+amsterdam
# Processing Record 20 of Set 6 | new amsterdam
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=basco
# Processing Record 21 of Set 6 | basco
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bathsheba
# Processing Record 22 of Set 6 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=hasaki
# Processing Record 23 of Set 6 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=damghan
# Processing Record 24 of Set 6 | damghan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=provideniya
# Processing Record 25 of Set 6 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=jujuy
# Processing Record 26 of Set 6 | jujuy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=avarua
# Processing Record 27 of Set 6 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=suleja
# Processing Record 28 of Set 6 | suleja
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=moussoro
# Processing Record 29 of Set 6 | moussoro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=roswell
# Processing Record 30 of Set 6 | roswell
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=iqaluit
# Processing Record 31 of Set 6 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chihuahua
# Processing Record 32 of Set 6 | chihuahua
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lazaro+cardenas
# Processing Record 33 of Set 6 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=musoma
# Processing Record 34 of Set 6 | musoma
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=alihe
# Processing Record 35 of Set 6 | alihe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ambilobe
# Processing Record 36 of Set 6 | ambilobe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ayolas
# Processing Record 37 of Set 6 | ayolas
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=dahra
# Processing Record 38 of Set 6 | dahra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=road+town
# Processing Record 39 of Set 6 | road town
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=raudeberg
# Processing Record 40 of Set 6 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=barentsburg
# Processing Record 41 of Set 6 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=carahue
# Processing Record 42 of Set 6 | carahue
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tazmalt
# Processing Record 43 of Set 6 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nunoa
# Processing Record 44 of Set 6 | nunoa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vila
# Processing Record 45 of Set 6 | vila
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ixtlan+del+rio
# Processing Record 46 of Set 6 | ixtlan del rio
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lompoc
# Processing Record 47 of Set 6 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=clyde+river
# Processing Record 48 of Set 6 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tsihombe
# Processing Record 49 of Set 6 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tres+arroyos
# Processing Record 50 of Set 6 | tres arroyos
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=flin+flon
# Processing Record 1 of Set 7 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sitka
# Processing Record 2 of Set 7 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=luderitz
# Processing Record 3 of Set 7 | luderitz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=utiroa
# Processing Record 4 of Set 7 | utiroa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bressanone
# Processing Record 5 of Set 7 | bressanone
# ...
# Processing Record 16 of Set 14 | jesenice
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=andra
# Processing Record 17 of Set 14 | andra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+keats
# Processing Record 18 of Set 14 | port keats
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=guanica
# Processing Record 19 of Set 14 | guanica
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=contamana
# Processing Record 20 of Set 14 | contamana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=waw
# Processing Record 21 of Set 14 | waw
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chajul
# Processing Record 22 of Set 14 | chajul
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=pilao+arcado
# Processing Record 23 of Set 14 | pilao arcado
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lokomotivnyy
# Processing Record 24 of Set 14 | lokomotivnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=privolzhskiy
# Processing Record 25 of Set 14 | privolzhskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=harlev
# Processing Record 26 of Set 14 | harlev
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=qixia
# Processing Record 27 of Set 14 | qixia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=abu+samrah
# Processing Record 28 of Set 14 | abu samrah
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=stokmarknes
# Processing Record 29 of Set 14 | stokmarknes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=yinchuan
# Processing Record 30 of Set 14 | yinchuan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lysva
# Processing Record 31 of Set 14 | lysva
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vysokogornyy
# Processing Record 32 of Set 14 | vysokogornyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=valday
# Processing Record 33 of Set 14 | valday
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=terekli-mekteb
# Processing Record 34 of Set 14 | terekli-mekteb
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=assiniboia
# Processing Record 35 of Set 14 | assiniboia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=neyshabur
# Processing Record 36 of Set 14 | neyshabur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=wentzville
# Processing Record 37 of Set 14 | wentzville
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=voh
# Processing Record 38 of Set 14 | voh
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vozhega
# Processing Record 39 of Set 14 | vozhega
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=toliary
# Processing Record 40 of Set 14 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=pereslavl-zalesskiy
# Processing Record 41 of Set 14 | pereslavl-zalesskiy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=waipawa
# Processing Record 42 of Set 14 | waipawa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=agstafa
# Processing Record 43 of Set 14 | agstafa
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=port+moresby
# Processing Record 44 of Set 14 | port moresby
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=gat
# Processing Record 45 of Set 14 | gat
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mana
# Processing Record 46 of Set 14 | mana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=natchez
# Processing Record 47 of Set 14 | natchez
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=bolungarvik
# Processing Record 48 of Set 14 | bolungarvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=botwood
# Processing Record 49 of Set 14 | botwood
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=taonan
# Processing Record 50 of Set 14 | taonan
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=axim
# Processing Record 1 of Set 15 | axim
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=dingle
# Processing Record 2 of Set 15 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=solnechnyy
# Processing Record 3 of Set 15 | solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=xichang
# Processing Record 4 of Set 15 | xichang
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mirandopolis
# Processing Record 5 of Set 15 | mirandopolis
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=aripuana
# Processing Record 6 of Set 15 | aripuana
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tutoia
# Processing Record 7 of Set 15 | tutoia
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=shanghai
# Processing Record 8 of Set 15 | shanghai
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rabo+de+peixe
# Processing Record 9 of Set 15 | rabo de peixe
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=la+ronge
# Processing Record 10 of Set 15 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=shahr-e+babak
# Processing Record 11 of Set 15 | shahr-e babak
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=akalkot
# Processing Record 12 of Set 15 | akalkot
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chagoda
# Processing Record 13 of Set 15 | chagoda
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=buala
# Processing Record 14 of Set 15 | buala
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rancho+palos+verdes
# Processing Record 15 of Set 15 | rancho palos verdes
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=whitehorse
# Processing Record 16 of Set 15 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kizilskoye
# Processing Record 17 of Set 15 | kizilskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=karpogory
# Processing Record 18 of Set 15 | karpogory
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=burkhala
# Processing Record 19 of Set 15 | burkhala
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=san+quintin
# Processing Record 20 of Set 15 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=floro
# Processing Record 21 of Set 15 | floro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=ancud
# Processing Record 22 of Set 15 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=washougal
# Processing Record 23 of Set 15 | washougal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=loukhi
# Processing Record 24 of Set 15 | loukhi
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saint-pierre
# Processing Record 25 of Set 15 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=baghdad
# Processing Record 26 of Set 15 | baghdad
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=betare+oya
# Processing Record 27 of Set 15 | betare oya
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=gravdal
# Processing Record 28 of Set 15 | gravdal
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nemuro
# Processing Record 29 of Set 15 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=rafiganj
# Processing Record 30 of Set 15 | rafiganj
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=villa+carlos+paz
# Processing Record 31 of Set 15 | villa carlos paz
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=uvarovka
# Processing Record 32 of Set 15 | uvarovka
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=tome-acu
# Processing Record 33 of Set 15 | tome-acu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=nauta
# Processing Record 34 of Set 15 | nauta
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=anton+lizardo
# Processing Record 35 of Set 15 | anton lizardo
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=matagami
# Processing Record 36 of Set 15 | matagami
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=husavik
# Processing Record 37 of Set 15 | husavik
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=high+level
# Processing Record 38 of Set 15 | high level
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=garissa
# Processing Record 39 of Set 15 | garissa
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chamonix-mont-blanc
# Processing Record 40 of Set 15 | chamonix-mont-blanc
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mitsamiouli
# Processing Record 41 of Set 15 | mitsamiouli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=xuddur
# Processing Record 42 of Set 15 | xuddur
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=vaitupu
# Processing Record 43 of Set 15 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=kargil
# Processing Record 44 of Set 15 | kargil
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=saskatoon
# Processing Record 45 of Set 15 | saskatoon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=katangli
# Processing Record 46 of Set 15 | katangli
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=mount+darwin
# Processing Record 47 of Set 15 | mount darwin
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=donskoye
# Processing Record 48 of Set 15 | donskoye
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=lebanon
# Processing Record 49 of Set 15 | lebanon
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=belmonte
# Processing Record 50 of Set 15 | belmonte
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=sao+joao+da+barra
# Processing Record 1 of Set 16 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=chingirlau
# Processing Record 2 of Set 16 | chingirlau
# http://api.openweathermap.org/data/2.5/weather?units=imperial&APPID=498fe666bdc2faddd2c04d37959b872a&q=naryan-mar
# Processing Record 3 of Set 16 | naryan-mar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# 685
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30240/978744680.py in <module>
#      54 output_data_file = "weather_data/WeatherPy_challenge.csv"
#      55 # Export the City_Data into a CSV.
# ---> 56 city_data_df.to_csv(output_data_file, index_label="City_ID")
#      57
#
# ~\AppData\Local\Continuum\miniconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\AppData\Local\Continuum\miniconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\AppData\Local\Continuum\miniconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\AppData\Local\Continuum\miniconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# PermissionError: [Errno 13] Permission denied: 'weather_data/WeatherPy_challenge.csv'

# %%
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      yellowknife      CA  62.4560 -114.3525     43.32        52           0
# 1        ostrovnoy      RU  68.0531   39.5131     14.77        93          51
# 2          ushuaia      AR -54.8000  -68.3000     42.46        70          20
# 3        concordia      AR -31.3930  -58.0209     59.79        67          63
# 4         klaksvik      FO  62.2266   -6.5890     40.12        72          89
# 5         khatanga      RU  71.9667  102.5000     16.23        87          82
# 6          karachi      PK  24.9056   67.0822     85.82        45          40
# 7          rikitea      PF -23.1203 -134.9692     76.46        70          20
# 8  bambous virieux      MU -20.3428   57.7575     73.22        94          20
# 9            seoul      KR  37.5683  126.9778     54.84        82          40
#
#    Wind Speed Current Description
# 0       13.80           clear sky
# 1        8.48       broken clouds
# 2       10.36          few clouds
# 3        3.00       broken clouds
# 4       22.91     overcast clouds
# 5       10.54       broken clouds
# 6       12.66    scattered clouds
# 7        5.48          few clouds
# 8        1.14          few clouds
# 9        3.44                mist
